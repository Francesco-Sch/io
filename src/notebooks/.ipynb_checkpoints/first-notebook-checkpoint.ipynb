# %% [markdown]
# # Hello World

# %%
import os
import io
import ipywidgets as widgets
from PIL import Image

# %%
uploader = widgets.FileUpload(
    accept='.jpg, .jpeg, .png',
    multiple=True
)

uploader
# Out:
# FileUpload(value={}, accept='.jpg, .jpeg, .png', description='Upload', multiple=True)

# %%
for x in uploader.value:
    image_data = uploader.value[x]['content']

    with open(f'../data/images/{x}', "wb") as fp:
        image_data = uploader.value[x]['content']
        fp.write(image_data)

    image = Image.open(io.BytesIO(image_data))
    image.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x630 at 0x7FB54DDD26A0>
